# %%
### Importation des

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import ast
from langdetect import detect
import langid
from mtranslate import translate
from sklearn.preprocessing import MinMaxScaler
from scipy import stats

# %%
df_1_2 = pd.read_csv('df_1-2.csv')
df_3_5 = pd.read_csv('df_3-5.csv')
df_6_10 = pd.read_csv('df_6-10.csv')
df_11_13 = pd.read_csv('df_11-13.csv')
df_14_19 = pd.read_csv('df_14-19.csv')
df_20_23 = pd.read_csv('df_20-23.csv')
df_24_27 = pd.read_csv('df_24-27.csv')
df_28_31 = pd.read_csv('df_28-31.csv')

# %%
df1 = pd.concat([df_1_2, df_3_5, df_6_10, df_11_13, df_14_19, df_20_23, df_24_27, df_28_31])

# %%
df1.shape
# Out:
# (31000, 84)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31000 entries, 0 to 3999
# Data columns (total 84 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           31000 non-null  int64
#  1   node_id                      31000 non-null  object
#  2   name                         31000 non-null  object
#  3   full_name                    31000 non-null  object
#  4   private                      31000 non-null  bool
#  5   owner                        31000 non-null  object
#  6   html_url                     31000 non-null  object
#  7   description                  22099 non-null  object
#  8   fork                         31000 non-null  bool
#  9   url                          31000 non-null  object
#  10  forks_url                    31000 non-null  object
#  11  keys_url                     31000 non-null  object
#  12  collaborators_url            31000 non-null  object
#  13  teams_url                    31000 non-null  object
#  14  hooks_url                    31000 non-null  object
#  15  issue_events_url             31000 non-null  object
#  16  events_url                   31000 non-null  object
#  17  assignees_url                31000 non-null  object
#  18  branches_url                 31000 non-null  object
#  19  tags_url                     31000 non-null  object
#  20  blobs_url                    31000 non-null  object
#  21  git_tags_url                 31000 non-null  object
#  22  git_refs_url                 31000 non-null  object
#  23  trees_url                    31000 non-null  object
#  24  statuses_url                 31000 non-null  object
#  25  languages_url                31000 non-null  object
#  26  stargazers_url               31000 non-null  object
#  27  contributors_url             31000 non-null  object
#  28  subscribers_url              31000 non-null  object
#  29  subscription_url             31000 non-null  object
#  30  commits_url                  31000 non-null  object
#  31  git_commits_url              31000 non-null  object
#  32  comments_url                 31000 non-null  object
#  33  issue_comment_url            31000 non-null  object
#  34  contents_url                 31000 non-null  object
#  35  compare_url                  31000 non-null  object
#  36  merges_url                   31000 non-null  object
#  37  archive_url                  31000 non-null  object
#  38  downloads_url                31000 non-null  object
#  39  issues_url                   31000 non-null  object
#  40  pulls_url                    31000 non-null  object
#  41  milestones_url               31000 non-null  object
#  42  notifications_url            31000 non-null  object
#  43  labels_url                   31000 non-null  object
#  44  releases_url                 31000 non-null  object
#  45  deployments_url              31000 non-null  object
#  46  created_at                   31000 non-null  object
#  47  updated_at                   31000 non-null  object
#  48  pushed_at                    31000 non-null  object
#  49  git_url                      31000 non-null  object
#  50  ssh_url                      31000 non-null  object
#  51  clone_url                    31000 non-null  object
#  52  svn_url                      31000 non-null  object
#  53  homepage                     5319 non-null   object
#  54  size                         31000 non-null  int64
#  55  stargazers_count             31000 non-null  int64
#  56  watchers_count               31000 non-null  int64
#  57  language                     27624 non-null  object
#  58  has_issues                   31000 non-null  bool
#  59  has_projects                 31000 non-null  bool
#  60  has_downloads                31000 non-null  bool
#  61  has_wiki                     31000 non-null  bool
#  62  has_pages                    31000 non-null  bool
#  63  has_discussions              31000 non-null  bool
#  64  forks_count                  31000 non-null  int64
#  65  mirror_url                   0 non-null      float64
#  66  archived                     31000 non-null  bool
#  67  disabled                     31000 non-null  bool
#  68  open_issues_count            31000 non-null  int64
#  69  license                      13598 non-null  object
#  70  allow_forking                31000 non-null  bool
#  71  is_template                  31000 non-null  bool
#  72  web_commit_signoff_required  31000 non-null  bool
#  73  topics                       31000 non-null  object
#  74  visibility                   31000 non-null  object
#  75  forks                        31000 non-null  int64
#  76  open_issues                  31000 non-null  int64
#  77  watchers                     31000 non-null  int64
#  78  default_branch               31000 non-null  object
#  79  permissions                  31000 non-null  object
#  80  score                        31000 non-null  float64
#  81  languages                    31000 non-null  object
#  82  subscribers_count            31000 non-null  int64
#  83  Unnamed: 0                   7000 non-null   float64
# dtypes: bool(13), float64(3), int64(10), object(58)
# memory usage: 17.4+ MB

# %%
columns_to_save = ['id', 'node_id','full_name', 'description', 'created_at', 'updated_at', 
                   'pushed_at', 'size', 'languages', 'has_issues', 'has_projects', 'has_downloads', 'has_wiki', 
                   'has_pages', 'has_discussions', 'archived', 'disabled', 'is_template', 'web_commit_signoff_required', 
                   'forks', 'open_issues','stargazers_count', 'default_branch', 'score', 'subscribers_count']

df = df1[columns_to_save]

# %%
duplicates_count = df.duplicated().sum()
duplicates_count
# Out:
# 4135

# %%
df = df.drop_duplicates()
df.shape
# Out:
# (26865, 25)

# %%
nan_count = df.isna().sum().sum()
nan_count
# Out:
# 7642

# %%
df['description'] = df['description'].fillna('without description')

# %%
values_negatife = df[df['id'] < 0]
values_negatife
# Out:
# Empty DataFrame
# Columns: [id, node_id, full_name, description, created_at, updated_at, pushed_at, size, languages, has_issues, has_projects, has_downloads, has_wiki, has_pages, has_discussions, archived, disabled, is_template, web_commit_signoff_required, forks, open_issues, stargazers_count, default_branch, score, subscribers_count]
# Index: []
#
# [0 rows x 25 columns]

# %%
df['created_at'] = pd.to_datetime(df['created_at'])
df['updated_at'] = pd.to_datetime(df['updated_at'])
df['pushed_at'] = pd.to_datetime(df['pushed_at'])
df['web_commit_signoff_required'] = df['web_commit_signoff_required'].astype(bool)

# %% [markdown]
# ## Traitement des Langues

# %%
df['languages'] = df['languages'].apply(lambda x: ast.literal_eval(x))

df['language_keys'] = df['languages'].apply(lambda x: list(x.keys()))
df['language_values'] = df['languages'].apply(lambda x: list(x.values()))

# %%
empty_lists = (df['language_keys'].apply(len) == 0) & (df['language_values'].apply(len) == 0)

df = df[~empty_lists].reset_index(drop=True)
df
# Out:
#               id       node_id  \
# 0      584280578  R_kgDOItNqAg
# 1      584528479  R_kgDOItcyXw
# 2      584494922  R_kgDOItavSg
# 3      584299779  R_kgDOItO1Aw
# 4      584498613  R_kgDOIta9tQ
# ...          ...           ...
# 12099  595575277  R_kgDOI3_B7Q
# 12100  595739226  R_kgDOI4JCWg
# 12101  595468878  R_kgDOI34iTg
# 12102  595853234  R_kgDOI4P_sg
# 12103  595584357  R_kgDOI3_lZQ
#
#                                             full_name  \
# 0                              data-storage-lab/ConfD
# 1                     exyte/android-waves-progressbar
# 2                         Sid-WC121/StopWatch-ReactJS
# 3                  chichuDlong/CppPracticeForOpenFOAM
# 4      nlztrk/OTTO-Multi-Objective-Recommender-System
# ...                                               ...
# 12099                              U7P4L-IN/FAKE-MAIL
# 12100                            felippe-regazio/wcwc
# 12101                           abderox/X-game-socket
# 12102             accrescent/bundletool-gradle-plugin
# 12103                 jeffreyohene/Rayshader-Projects
#
#                                              description  \
# 0      Analyzing Configuration Dependencies of File S...
# 1      A depth gauge progress bar, inspired by Apple ...
# 2                                    without description
# 3                                    OpenFOAM框架下Cpp的基本应用
# 4                                    without description
# ...                                                  ...
# 12099                        😺FAKE MAIL SENDING COMMAND😸
# 12100                          Write Cool Web Components
# 12101  Through this project, I am aiming to learn mor...
# 12102            A Gradle plugin for Google's bundletool
# 12103                 Repo of map vizzes using rayshader
#
#                      created_at                updated_at  \
# 0     2023-01-02 05:05:41+00:00 2023-03-03 18:39:13+00:00
# 1     2023-01-02 20:35:10+00:00 2023-06-22 15:21:57+00:00
# 2     2023-01-02 18:19:19+00:00 2023-02-13 17:19:36+00:00
# 3     2023-01-02 06:45:33+00:00 2023-03-23 02:55:14+00:00
# 4     2023-01-02 18:33:05+00:00 2023-03-14 01:13:20+00:00
# ...                         ...                       ...
# 12099 2023-01-31 11:18:56+00:00 2023-06-16 18:01:25+00:00
# 12100 2023-01-31 17:59:45+00:00 2023-02-19 19:28:53+00:00
# 12101 2023-01-31 06:16:00+00:00 2023-05-27 18:18:46+00:00
# 12102 2023-01-31 23:59:40+00:00 2023-03-24 16:16:47+00:00
# 12103 2023-01-31 11:44:42+00:00 2023-04-03 12:26:23+00:00
#
#                       pushed_at  size  \
# 0     2023-03-03 18:43:53+00:00   131
# 1     2023-06-03 10:13:56+00:00   120
# 2     2023-01-03 16:25:31+00:00    18
# 3     2023-03-23 01:26:16+00:00  3901
# 4     2023-01-31 19:52:25+00:00   124
# ...                         ...   ...
# 12099 2023-01-31 12:51:49+00:00    12
# 12100 2023-06-15 03:33:44+00:00   470
# 12101 2023-02-03 00:47:29+00:00  3171
# 12102 2023-06-07 21:39:25+00:00   184
# 12103 2023-04-27 18:51:44+00:00    11
#
#                                                languages  has_issues  ...  \
# 0      {'Roff': 0.4032792497585191, 'Python': 0.34478...        True  ...
# 1                                        {'Kotlin': 1.0}        True  ...
# 2      {'JavaScript': 0.5668016194331984, 'CSS': 0.37...        True  ...
# 3      {'C++': 0.9890864817137718, 'C': 0.01077777005...        True  ...
# 4                              {'Jupyter Notebook': 1.0}        True  ...
# ...                                                  ...         ...  ...
# 12099                                    {'Python': 1.0}        True  ...
# 12100  {'TypeScript': 0.5158642462509866, 'JavaScript...        True  ...
# 12101  {'TypeScript': 0.8648237476808905, 'CSS': 0.05...        True  ...
# 12102                                    {'Kotlin': 1.0}        True  ...
# 12103                                         {'R': 1.0}        True  ...
#
#        is_template  web_commit_signoff_required  forks  open_issues  \
# 0            False                        False      0            0
# 1            False                        False      1            0
# 2            False                        False      0            0
# 3            False                        False      5            0
# 4            False                        False      0            0
# ...            ...                          ...    ...          ...
# 12099        False                        False      0            0
# 12100        False                        False      0            0
# 12101        False                        False      0            0
# 12102        False                        False      0            2
# 12103        False                        False      0            0
#
#        stargazers_count  default_branch  score  subscribers_count  \
# 0                     8            main    1.0                  1
# 1                     8          master    1.0                  4
# 2                     8            main    1.0                  1
# 3                     8          master    1.0                  1
# 4                     8            main    1.0                  1
# ...                 ...             ...    ...                ...
# 12099                 6            main    1.0                  1
# 12100                 6            main    1.0                  1
# 12101                 6          master    1.0                  1
# 12102                 6            main    1.0                  2
# 12103                 6            main    1.0                  0
#
#                              language_keys  \
# 0        [Roff, Python, C++, Shell, CMake]
# 1                                 [Kotlin]
# 2                  [JavaScript, CSS, HTML]
# 3                          [C++, C, Shell]
# 4                       [Jupyter Notebook]
# ...                                    ...
# 12099                             [Python]
# 12100       [TypeScript, JavaScript, HTML]
# 12101  [TypeScript, CSS, HTML, JavaScript]
# 12102                             [Kotlin]
# 12103                                  [R]
#
#                                          language_values
# 0      [0.4032792497585191, 0.3447899217887113, 0.216...
# 1                                                  [1.0]
# 2      [0.5668016194331984, 0.37972916375820187, 0.05...
# 3      [0.9890864817137718, 0.010777770058650972, 0.0...
# 4                                                  [1.0]
# ...                                                  ...
# 12099                                              [1.0]
# 12100  [0.5158642462509866, 0.46650881347013945, 0.01...
# 12101  [0.8648237476808905, 0.05929499072356215, 0.03...
# 12102                                              [1.0]
# 12103                                              [1.0]
#
# [12104 rows x 27 columns]

# %% [markdown]
# ## correction des format et supprime la colon original

# %%
df['language_values'] = df['language_values'].apply(lambda x: [f'{value*100:.2f}%' for value in x])

# %%
df = df.drop('languages', axis=1)

# %%
df = df.rename(columns={'subscribers_count': 'watchers'})
df = df.rename(columns={'stargazers_count': 'star'})
df = df.rename(columns={'language_values': 'language_percent'})
df = df.rename(columns={'language_keys': 'language_name'})

# %%
df.shape
# Out:
# (12104, 26)

# %% [markdown]
# ## vérifier le valeurs null et vide

# %%
df.isna().sum()
# Out:
# id                             0
# node_id                        0
# full_name                      0
# description                    0
# created_at                     0
# updated_at                     0
# pushed_at                      0
# size                           0
# has_issues                     0
# has_projects                   0
# has_downloads                  0
# has_wiki                       0
# has_pages                      0
# has_discussions                0
# archived                       0
# disabled                       0
# is_template                    0
# web_commit_signoff_required    0
# forks                          0
# open_issues                    0
# star                           0
# default_branch                 0
# score                          0
# watchers                       0
# language_name                  0
# language_percent               0
# dtype: int64

# %%
empty_count = (df == '').sum().sum()
empty_count
# Out:
# 0

# %%
df
# Out:
#               id       node_id  \
# 0      584280578  R_kgDOItNqAg
# 1      584528479  R_kgDOItcyXw
# 2      584494922  R_kgDOItavSg
# 3      584299779  R_kgDOItO1Aw
# 4      584498613  R_kgDOIta9tQ
# ...          ...           ...
# 12099  595575277  R_kgDOI3_B7Q
# 12100  595739226  R_kgDOI4JCWg
# 12101  595468878  R_kgDOI34iTg
# 12102  595853234  R_kgDOI4P_sg
# 12103  595584357  R_kgDOI3_lZQ
#
#                                             full_name  \
# 0                              data-storage-lab/ConfD
# 1                     exyte/android-waves-progressbar
# 2                         Sid-WC121/StopWatch-ReactJS
# 3                  chichuDlong/CppPracticeForOpenFOAM
# 4      nlztrk/OTTO-Multi-Objective-Recommender-System
# ...                                               ...
# 12099                              U7P4L-IN/FAKE-MAIL
# 12100                            felippe-regazio/wcwc
# 12101                           abderox/X-game-socket
# 12102             accrescent/bundletool-gradle-plugin
# 12103                 jeffreyohene/Rayshader-Projects
#
#                                              description  \
# 0      Analyzing Configuration Dependencies of File S...
# 1      A depth gauge progress bar, inspired by Apple ...
# 2                                    without description
# 3                                    OpenFOAM框架下Cpp的基本应用
# 4                                    without description
# ...                                                  ...
# 12099                        😺FAKE MAIL SENDING COMMAND😸
# 12100                          Write Cool Web Components
# 12101  Through this project, I am aiming to learn mor...
# 12102            A Gradle plugin for Google's bundletool
# 12103                 Repo of map vizzes using rayshader
#
#                      created_at                updated_at  \
# 0     2023-01-02 05:05:41+00:00 2023-03-03 18:39:13+00:00
# 1     2023-01-02 20:35:10+00:00 2023-06-22 15:21:57+00:00
# 2     2023-01-02 18:19:19+00:00 2023-02-13 17:19:36+00:00
# 3     2023-01-02 06:45:33+00:00 2023-03-23 02:55:14+00:00
# 4     2023-01-02 18:33:05+00:00 2023-03-14 01:13:20+00:00
# ...                         ...                       ...
# 12099 2023-01-31 11:18:56+00:00 2023-06-16 18:01:25+00:00
# 12100 2023-01-31 17:59:45+00:00 2023-02-19 19:28:53+00:00
# 12101 2023-01-31 06:16:00+00:00 2023-05-27 18:18:46+00:00
# 12102 2023-01-31 23:59:40+00:00 2023-03-24 16:16:47+00:00
# 12103 2023-01-31 11:44:42+00:00 2023-04-03 12:26:23+00:00
#
#                       pushed_at  size  has_issues  has_projects  ...  \
# 0     2023-03-03 18:43:53+00:00   131        True          True  ...
# 1     2023-06-03 10:13:56+00:00   120        True          True  ...
# 2     2023-01-03 16:25:31+00:00    18        True          True  ...
# 3     2023-03-23 01:26:16+00:00  3901        True          True  ...
# 4     2023-01-31 19:52:25+00:00   124        True          True  ...
# ...                         ...   ...         ...           ...  ...
# 12099 2023-01-31 12:51:49+00:00    12        True          True  ...
# 12100 2023-06-15 03:33:44+00:00   470        True          True  ...
# 12101 2023-02-03 00:47:29+00:00  3171        True          True  ...
# 12102 2023-06-07 21:39:25+00:00   184        True         False  ...
# 12103 2023-04-27 18:51:44+00:00    11        True          True  ...
#
#        is_template  web_commit_signoff_required  forks  open_issues  star  \
# 0            False                        False      0            0     8
# 1            False                        False      1            0     8
# 2            False                        False      0            0     8
# 3            False                        False      5            0     8
# 4            False                        False      0            0     8
# ...            ...                          ...    ...          ...   ...
# 12099        False                        False      0            0     6
# 12100        False                        False      0            0     6
# 12101        False                        False      0            0     6
# 12102        False                        False      0            2     6
# 12103        False                        False      0            0     6
#
#        default_branch  score  watchers                        language_name  \
# 0                main    1.0         1    [Roff, Python, C++, Shell, CMake]
# 1              master    1.0         4                             [Kotlin]
# 2                main    1.0         1              [JavaScript, CSS, HTML]
# 3              master    1.0         1                      [C++, C, Shell]
# 4                main    1.0         1                   [Jupyter Notebook]
# ...               ...    ...       ...                                  ...
# 12099            main    1.0         1                             [Python]
# 12100            main    1.0         1       [TypeScript, JavaScript, HTML]
# 12101          master    1.0         1  [TypeScript, CSS, HTML, JavaScript]
# 12102            main    1.0         2                             [Kotlin]
# 12103            main    1.0         0                                  [R]
#
#                              language_percent
# 0      [40.33%, 34.48%, 21.68%, 2.87%, 0.64%]
# 1                                   [100.00%]
# 2                     [56.68%, 37.97%, 5.35%]
# 3                      [98.91%, 1.08%, 0.01%]
# 4                                   [100.00%]
# ...                                       ...
# 12099                               [100.00%]
# 12100                 [51.59%, 46.65%, 1.76%]
# 12101           [86.48%, 5.93%, 3.83%, 3.76%]
# 12102                               [100.00%]
# 12103                               [100.00%]
#
# [12104 rows x 26 columns]

# %% [markdown]
# ## nettoyer et traduit la colon description

# %%
pattern = r'[^\w\s\u4E00-\u9FFF]'
df['description'] = df['description'].apply(lambda x: re.sub(pattern, '', x))
df['description'] = df['description'].replace(r'\s+', ' ', regex=True)

# %%
df['description'] = df['description'].apply(lambda x: translate(x, 'en') if langid.classify(x)[0] != 'en' else x)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13748\2089351565.py in <module>
# ----> 1 df['description'] = df['description'].apply(lambda x: translate(x, 'en') if langid.classify(x)[0] != 'en' else x)
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4431         dtype: float64
#    4432         """
# -> 4433         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4434
#    4435     def _reduce(
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#    1086             return self.apply_str()
#    1087
# -> 1088         return self.apply_standard()
#    1089
#    1090     def agg(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1141                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1142                 # "Callable[[Any], Any]"
# -> 1143                 mapped = lib.map_infer(
#    1144                     values,
#    1145                     f,  # type: ignore[arg-type]
#
# ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ~\AppData\Local\Temp\ipykernel_13748\2089351565.py in <lambda>(x)
# ----> 1 df['description'] = df['description'].apply(lambda x: translate(x, 'en') if langid.classify(x)[0] != 'en' else x)
#
# ~\anaconda3\lib\site-packages\mtranslate\core.py in translate(to_translate, to_language, from_language)
#      78         link = base_link % (to_language, from_language, to_translate)
#      79         request = urllib.request.Request(link, headers=agent)
# ---> 80         raw_data = urllib.request.urlopen(request).read()
#      81     data = raw_data.decode("utf-8")
#      82     expr = r'(?s)class="(?:t0|result-container)">(.*?)<'
#
# ~\anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212     else:
#     213         opener = _opener
# --> 214     return opener.open(url, data, timeout)
#     215
#     216 def install_opener(opener):
#
# ~\anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     521         for processor in self.process_response.get(protocol, []):
#     522             meth = getattr(processor, meth_name)
# --> 523             response = meth(req, response)
#     524
#     525         return response
#
# ~\anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     630         # request was successfully received, understood, and accepted.
#     631         if not (200 <= code < 300):
# --> 632             response = self.parent.error(
#     633                 'http', request, response, code, msg, hdrs)
#     634
#
# ~\anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     553             http_err = 0
#     554         args = (dict, proto, meth_name) + args
# --> 555         result = self._call_chain(*args)
#     556         if result:
#     557             return result
#
# ~\anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     492         for handler in handlers:
#     493             func = getattr(handler, meth_name)
# --> 494             result = func(*args)
#     495             if result is not None:
#     496                 return result
#
# ~\anaconda3\lib\urllib\request.py in http_error_302(self, req, fp, code, msg, headers)
#     745         fp.close()
#     746
# --> 747         return self.parent.open(new, timeout=req.timeout)
#     748
#     749     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# ~\anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     515
#     516         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 517         response = self._open(req, data)
#     518
#     519         # post-process response
#
# ~\anaconda3\lib\urllib\request.py in _open(self, req, data)
#     532
#     533         protocol = req.type
# --> 534         result = self._call_chain(self.handle_open, protocol, protocol +
#     535                                   '_open', req)
#     536         if result:
#
# ~\anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     492         for handler in handlers:
#     493             func = getattr(handler, meth_name)
# --> 494             result = func(*args)
#     495             if result is not None:
#     496                 return result
#
# ~\anaconda3\lib\urllib\request.py in https_open(self, req)
#    1387
#    1388         def https_open(self, req):
# -> 1389             return self.do_open(http.client.HTTPSConnection, req,
#    1390                 context=self._context, check_hostname=self._check_hostname)
#    1391
#
# ~\anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1344         try:
#    1345             try:
# -> 1346                 h.request(req.get_method(), req.selector, req.data, headers,
#    1347                           encode_chunked=req.has_header('Transfer-encoding'))
#    1348             except OSError as err: # timeout error
#
# ~\anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1283                 encode_chunked=False):
#    1284         """Send a complete request to the server."""
# -> 1285         self._send_request(method, url, body, headers, encode_chunked)
#    1286
#    1287     def _send_request(self, method, url, body, headers, encode_chunked):
#
# ~\anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1329             # default charset of iso-8859-1.
#    1330             body = _encode(body, 'body')
# -> 1331         self.endheaders(body, encode_chunked=encode_chunked)
#    1332
#    1333     def getresponse(self):
#
# ~\anaconda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1278         else:
#    1279             raise CannotSendHeader()
# -> 1280         self._send_output(message_body, encode_chunked=encode_chunked)
#    1281
#    1282     def request(self, method, url, body=None, headers={}, *,
#
# ~\anaconda3\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1038         msg = b"\r\n".join(self._buffer)
#    1039         del self._buffer[:]
# -> 1040         self.send(msg)
#    1041
#    1042         if message_body is not None:
#
# ~\anaconda3\lib\http\client.py in send(self, data)
#     978         if self.sock is None:
#     979             if self.auto_open:
# --> 980                 self.connect()
#     981             else:
#     982                 raise NotConnected()
#
# ~\anaconda3\lib\http\client.py in connect(self)
#    1452                 server_hostname = self.host
#    1453
# -> 1454             self.sock = self._context.wrap_socket(self.sock,
#    1455                                                   server_hostname=server_hostname)
#    1456
#
# ~\anaconda3\lib\ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     499         # SSLSocket class handles server_hostname encoding before it calls
#     500         # ctx._wrap_socket()
# --> 501         return self.sslsocket_class._create(
#     502             sock=sock,
#     503             server_side=server_side,
#
# ~\anaconda3\lib\ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1039                         # non-blocking
#    1040                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1041                     self.do_handshake()
#    1042             except (OSError, ValueError):
#    1043                 self.close()
#
# ~\anaconda3\lib\ssl.py in do_handshake(self, block)
#    1308             if timeout == 0.0 and block:
#    1309                 self.settimeout(None)
# -> 1310             self._sslobj.do_handshake()
#    1311         finally:
#    1312             self.settimeout(timeout)
#
# KeyboardInterrupt:

# %%
df.description
# Out:
# 0        Analyzing Configuration Dependencies of File S...
# 1        A depth gauge progress bar inspired by Apple W...
# 2                                      without description
# 3        The basic application of Cpp under the framewo...
# 4                                      without description
#                                ...
# 12099                            FAKE MAIL SENDING COMMAND
# 12100                            Write Cool Web Components
# 12101    Through this project I am aiming to learn more...
# 12102               A Gradle plugin for Googles bundletool
# 12103                   Repo of map vizzes using rayshader
# Name: description, Length: 11560, dtype: object

# %%
df['description'] = df['description'].str.strip()

# %%
df['description'] = df['description'].str.lower()

# %% [markdown]
# ## Détection et Traitement des Valeurs Aberrantes

# %%
numerical_columns = ['size', 'forks', 'open_issues', 'star', 'score', 'watchers']

outlier_counts = {}

for column in numerical_columns:
    z_scores = stats.zscore(df[column])
    threshold = 3
    outlier_indices = np.where(z_scores > threshold)[0]
    outlier_count = len(outlier_indices)
    
    outlier_counts[column] = outlier_count

print("Number of outliers in each column:")
for column, count in outlier_counts.items():
    print(f"{column}: {count}")
# Out:
# Number of outliers in each column:
# size: 56
# forks: 58
# open_issues: 73
# star: 35
# score: 0
# watchers: 217

# %%
normalized_columns = ['size', 'forks', 'open_issues',
                      'star', 'score', 'watchers']

fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(12, 8))

for i, column in enumerate(normalized_columns):
    ax = axes[i // 3, i % 3]
    ax.boxplot(df[column])
    ax.set_title(column)

plt.tight_layout()
plt.show()

# %%
lower_limit = 0.01
upper_limit = 0.99

# size
winsorized_size = np.clip(df['size'], df['size'].quantile(lower_limit), df['size'].quantile(upper_limit))
df['winsorized_size'] = winsorized_size

# forks
winsorized_forks = np.clip(df['forks'], df['forks'].quantile(lower_limit), df['forks'].quantile(upper_limit))
df['winsorized_forks'] = winsorized_forks

# open_issues
winsorized_open_issues = np.clip(df['open_issues'], df['open_issues'].quantile(lower_limit), df['open_issues'].quantile(upper_limit))
df['winsorized_open_issues'] = winsorized_open_issues

# star
winsorized_star = np.clip(df['star'], df['star'].quantile(lower_limit), df['star'].quantile(upper_limit))
df['winsorized_star'] = winsorized_star

# score
winsorized_score = np.clip(df['score'], df['score'].quantile(lower_limit), df['score'].quantile(upper_limit))
df['winsorized_score'] = winsorized_score

# watchers
winsorized_watchers = np.clip(df['watchers'], df['watchers'].quantile(lower_limit), df['watchers'].quantile(upper_limit))
df['winsorized_watchers'] = winsorized_watchers

# %%
columns_to_plot = ['winsorized_size', 'winsorized_forks', 'winsorized_open_issues', 'winsorized_star', 'winsorized_score', 'winsorized_watchers']

plt.figure(figsize=(10, 6))
df[columns_to_plot].boxplot()
plt.title('Box Plot of Winsorized Columns')
plt.xlabel('Column')
plt.ylabel('Value')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## statistiques

# %%
normalized_columns = ['forks', 'open_issues',
                      'star', 'score', 'watchers']

for column in normalized_columns:
    min_value = df[column].min()
    max_value = df[column].max()
    mean_value = df[column].mean()
    std_value = df[column].std()
    
    print(f"Column: {column}")
    print(f"Min value: {min_value}")
    print(f"Max value: {max_value}")
    print(f"Mean value: {mean_value}")
    print(f"Standard deviation: {std_value}")
    print()
# Out:
# Column: forks
# Min value: 0
# Max value: 2068
# Mean value: 4.140945142101785
# Standard deviation: 31.806868789958934
#
# Column: open_issues
# Min value: 0
# Max value: 669
# Mean value: 1.723479841374752
# Standard deviation: 11.794031931942389
#
# Column: star
# Min value: 3
# Max value: 21790
# Mean value: 25.33212161269002
# Standard deviation: 259.7118753345543
#
# Column: score
# Min value: 1.0
# Max value: 1.0
# Mean value: 1.0
# Standard deviation: 0.0
#
# Column: watchers
# Min value: 0
# Max value: 30
# Mean value: 2.110872438863186
# Standard deviation: 2.748561538369436

# %%
df
# Out:
#               id       node_id  \
# 0      584280578  R_kgDOItNqAg
# 1      584528479  R_kgDOItcyXw
# 2      584494922  R_kgDOItavSg
# 3      584299779  R_kgDOItO1Aw
# 4      584498613  R_kgDOIta9tQ
# ...          ...           ...
# 12099  595575277  R_kgDOI3_B7Q
# 12100  595739226  R_kgDOI4JCWg
# 12101  595468878  R_kgDOI34iTg
# 12102  595853234  R_kgDOI4P_sg
# 12103  595584357  R_kgDOI3_lZQ
#
#                                             full_name  \
# 0                              data-storage-lab/ConfD
# 1                     exyte/android-waves-progressbar
# 2                         Sid-WC121/StopWatch-ReactJS
# 3                  chichuDlong/CppPracticeForOpenFOAM
# 4      nlztrk/OTTO-Multi-Objective-Recommender-System
# ...                                               ...
# 12099                              U7P4L-IN/FAKE-MAIL
# 12100                            felippe-regazio/wcwc
# 12101                           abderox/X-game-socket
# 12102             accrescent/bundletool-gradle-plugin
# 12103                 jeffreyohene/Rayshader-Projects
#
#                                              description  \
# 0      analyzing configuration dependencies of file s...
# 1      a depth gauge progress bar inspired by apple w...
# 2                                    without description
# 3                                    openfoam框架下cpp的基本应用
# 4                                    without description
# ...                                                  ...
# 12099                          fake mail sending command
# 12100                          write cool web components
# 12101  through this project i am aiming to learn more...
# 12102             a gradle plugin for googles bundletool
# 12103                 repo of map vizzes using rayshader
#
#                      created_at                updated_at  \
# 0     2023-01-02 05:05:41+00:00 2023-03-03 18:39:13+00:00
# 1     2023-01-02 20:35:10+00:00 2023-06-22 15:21:57+00:00
# 2     2023-01-02 18:19:19+00:00 2023-02-13 17:19:36+00:00
# 3     2023-01-02 06:45:33+00:00 2023-03-23 02:55:14+00:00
# 4     2023-01-02 18:33:05+00:00 2023-03-14 01:13:20+00:00
# ...                         ...                       ...
# 12099 2023-01-31 11:18:56+00:00 2023-06-16 18:01:25+00:00
# 12100 2023-01-31 17:59:45+00:00 2023-02-19 19:28:53+00:00
# 12101 2023-01-31 06:16:00+00:00 2023-05-27 18:18:46+00:00
# 12102 2023-01-31 23:59:40+00:00 2023-03-24 16:16:47+00:00
# 12103 2023-01-31 11:44:42+00:00 2023-04-03 12:26:23+00:00
#
#                       pushed_at  size  has_issues  has_projects  ...  score  \
# 0     2023-03-03 18:43:53+00:00   131        True          True  ...    1.0
# 1     2023-06-03 10:13:56+00:00   120        True          True  ...    1.0
# 2     2023-01-03 16:25:31+00:00    18        True          True  ...    1.0
# 3     2023-03-23 01:26:16+00:00  3901        True          True  ...    1.0
# 4     2023-01-31 19:52:25+00:00   124        True          True  ...    1.0
# ...                         ...   ...         ...           ...  ...    ...
# 12099 2023-01-31 12:51:49+00:00    12        True          True  ...    1.0
# 12100 2023-06-15 03:33:44+00:00   470        True          True  ...    1.0
# 12101 2023-02-03 00:47:29+00:00  3171        True          True  ...    1.0
# 12102 2023-06-07 21:39:25+00:00   184        True         False  ...    1.0
# 12103 2023-04-27 18:51:44+00:00    11        True          True  ...    1.0
#
#        watchers                        language_name  \
# 0             1    [Roff, Python, C++, Shell, CMake]
# 1             4                             [Kotlin]
# 2             1              [JavaScript, CSS, HTML]
# 3             1                      [C++, C, Shell]
# 4             1                   [Jupyter Notebook]
# ...         ...                                  ...
# 12099         1                             [Python]
# 12100         1       [TypeScript, JavaScript, HTML]
# 12101         1  [TypeScript, CSS, HTML, JavaScript]
# 12102         2                             [Kotlin]
# 12103         0                                  [R]
#
#                              language_percent  winsorized_size  \
# 0      [40.33%, 34.48%, 21.68%, 2.87%, 0.64%]            131.0
# 1                                   [100.00%]            120.0
# 2                     [56.68%, 37.97%, 5.35%]             18.0
# 3                      [98.91%, 1.08%, 0.01%]           3901.0
# 4                                   [100.00%]            124.0
# ...                                       ...              ...
# 12099                               [100.00%]             12.0
# 12100                 [51.59%, 46.65%, 1.76%]            470.0
# 12101           [86.48%, 5.93%, 3.83%, 3.76%]           3171.0
# 12102                               [100.00%]            184.0
# 12103                               [100.00%]             11.0
#
#        winsorized_forks  winsorized_open_issues  winsorized_star  \
# 0                   0.0                     0.0              8.0
# 1                   1.0                     0.0              8.0
# 2                   0.0                     0.0              8.0
# 3                   5.0                     0.0              8.0
# 4                   0.0                     0.0              8.0
# ...                 ...                     ...              ...
# 12099               0.0                     0.0              6.0
# 12100               0.0                     0.0              6.0
# 12101               0.0                     0.0              6.0
# 12102               0.0                     2.0              6.0
# 12103               0.0                     0.0              6.0
#
#        winsorized_score  winsorized_watchers
# 0                   1.0                  1.0
# 1                   1.0                  4.0
# 2                   1.0                  1.0
# 3                   1.0                  1.0
# 4                   1.0                  1.0
# ...                 ...                  ...
# 12099               1.0                  1.0
# 12100               1.0                  1.0
# 12101               1.0                  1.0
# 12102               1.0                  2.0
# 12103               1.0                  0.0
#
# [12104 rows x 32 columns]
